# %% [markdown]
# # QAwiki Model 01
#
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys
from IPython.display import clear_output as clr
import time
import tensorflow as tf
import keras as K
import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer as WNL
# %matplotlib inline

# %%
# Setting Working Dircetory
cw_path = os.getcwd() + '/../../'
os.listdir(cw_path)
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'Datasets',
#  'dev-evaluate-v2.0-in1.json',
#  'Embeddings',
#  'evaluate-v2.0.py',
#  'Models',
#  'Readings',
#  'README.md']

# %% [markdown]
# ### Creating a Preprocessor

# %%
class preprocessor:
    
    def __init__(self):
        # word lemmatizer
        self.articles = 'a|an|and|the'
        self.lemmatizer = WNL()
        self.punctuations = string.punctuation
        self.translator = str.maketrans(string.punctuation, ' '*len(self.punctuations))
        
    def normalize_text(self, s):
        lower_s = self.lower(s)
        rem_p_s = self.remove_punc(lower_s)
        rem_a_s = self.remove_articles(rem_p_s)
        space_s = self.white_space_fix(rem_a_s)
        lemma_s = self.lemmatize(space_s)
        return lemma_s
        
    def lemmatize(self, txt):
        lemmatizer = self.lemmatizer
        return ' '.join(lemmatizer.lemmatize(lemmatizer.lemmatize(word, pos = 'v'), pos = 'a') for word in txt.split())

    def remove_articles(self, text):
        return re.sub('\s+('+self.articles+')(\s+)', ' ',text)

    def white_space_fix(self, text):
        return ' '.join(text.split())

    def remove_punc(self, text):
        return text.translate(self.translator)

    def lower(self, text):
        return text.lower()

# %%
class embedder:
    
    def __init__(self, embeddingfile = None):
        self.GloveEmbeddings = {}
        self.emb_dim = None
        if(embeddingfile is None):
            pass
        else:
            self.loadEmbeddings(embeddingfile)

    def loadEmbeddings(self, embeddingfile):

        fe = open(embeddingfile,"r",encoding="utf-8",errors="ignore")
        for line in fe:
            tokens= line.strip().split()
            word = tokens[0]
            vec = tokens[1:]
            vec = " ".join(vec)
            self.GloveEmbeddings[word]=vec
        self.emb_dim = len(vec.split(' '))
        #Add Zerovec, this will be useful to pad zeros, it is better to experiment with padding any non-zero constant values also.
        self.GloveEmbeddings["zerovec"] = "0.0 "*(self.emb_dim-1) + "0.0"
        fe.close()  


    def embed(self, text_batch, max_size):
        """
        text_batch : list of texts
        """
        batch_size = len(text_batch)
        emb_batch = np.zeros((batch_size, max_size, self.emb_dim))
        
        for i in range(batch_size):
            doc = text_batch[i]
            for j, word in enumerate(doc.strip().split()):
                if(j < max_size):
                    emb_batch[i,j,:] = np.array(self.GloveEmbeddings[word].strip().split(" ")).astype(float)
            
        return emb_batch

# %%
text_processor = preprocessor()

# %%
# Testing the [preprocessor]
text_processor.normalize_text("Hi I am Abhishek Kumar! How are You ?")
# Out:
# 'hi i be abhishek kumar how be you'

# %%
text_embedder = embedder(cw_path+'Embeddings/glove.6B.50d.txt')

# %%
# Testing the Embedder
text_embedder.embed(['hi how are you mister simond'],5).shape
# Out:
# (1, 5, 50)

# %%
# Global Parameters
emb_dim = text_embedder.emb_dim
time_size = 100
encoder_units = int(text_embedder.emb_dim//2)

# %%
# Checking params
print('Embeding_dim : ',emb_dim, ', Time Size :', time_size, ', Encoder_units :', encoder_units)
# Out:
# Embeding_dim :  50 , Time Size : 100 , Encoder_units : 25

# %%
class sentence_encoder:
    
    def __init__(self, sess, emd_dim, time_size, units, n_levels = 1):
        self.sess = sess
        self.emb_dim = emb_dim
        self.time_size = time_size
        self.n_levels = n_levels
        self.units = units
        self.make_encoding()
        
        
    def make_encoding(self):
        self.encoding = self.gen_transformer_graph()
    
    def gen_transformer_graph(self):
        
        self.input_text_vec = tf.placeholder(shape = [None, self.time_size, self.emb_dim], dtype=tf.float32)
        
        c_out = self.input_text_vec
        for k in range(self.n_levels):
            out = []
            for i in range(self.time_size):
                out.append(self.get_attension_graph(c_out))
            c_out = tf.nn.leaky_relu(tf.stack(out, axis = 1))
#             print(out)
        
        return c_out
            
            
            
    def get_attension_graph(self, seq):
        print(seq)
        dense = tf.layers.dense(seq, 1, activation=tf.nn.leaky_relu)
        print(dense)
        alphas = tf.nn.softmax(dense, axis = 1)
        print(alphas)
        out = tf.keras.layers.Dot(axes = 1)([alphas, seq])
        return out
    
    
    def get_encoding(self):
        
        return self.encoding

# %%
sess = tf.Session()
tf.reset_default_graph()

# %%
senc = sentence_encoder(sess, emb_dim, time_size, encoder_units)
# Out:
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_1:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_1/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_3:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_2/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_5:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_3/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_7:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_4/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_9:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_5/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_11:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_6/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_13:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_7/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_15:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_8/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_17:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_9/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_19:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_10/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_21:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_11/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_23:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_12/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_25:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_13/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_27:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_14/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_29:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_15/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_31:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_16/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_33:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_17/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_35:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_18/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_37:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_19/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_39:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_20/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_41:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_21/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_43:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_22/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_45:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_23/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_47:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_24/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_49:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_25/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_51:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_26/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_53:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_27/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_55:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_28/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_57:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_29/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_59:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_30/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_61:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_31/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_63:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_32/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_65:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_33/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_67:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_34/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_69:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_35/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_71:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_36/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_73:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_37/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_75:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_38/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_77:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_39/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_79:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_40/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_81:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_41/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_83:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_42/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_85:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_43/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_87:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_44/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_89:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_45/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_91:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_46/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_93:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_47/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_95:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_48/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_97:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_49/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_99:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_50/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_101:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_51/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_103:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_52/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_105:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_53/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_107:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_54/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_109:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_55/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_111:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_56/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_113:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_57/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_115:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_58/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_117:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_59/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_119:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_60/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_121:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_61/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_123:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_62/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_125:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_63/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_127:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_64/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_129:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_65/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_131:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_66/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_133:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_67/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_135:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_68/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_137:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_69/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_139:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_70/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_141:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_71/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_143:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_72/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_145:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_73/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_147:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_74/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_149:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_75/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_151:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_76/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_153:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_77/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_155:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_78/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_157:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_79/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_159:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_80/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_161:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_81/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_163:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_82/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_165:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_83/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_167:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_84/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_169:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_85/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_171:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_86/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_173:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_87/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_175:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_88/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_177:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_89/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_179:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_90/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_181:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_91/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_183:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_92/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_185:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_93/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_187:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_94/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_189:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_95/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_191:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_96/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_193:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_97/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_195:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_98/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_197:0", shape=(?, 100, 1), dtype=float32)
# Tensor("Placeholder:0", shape=(?, 100, 50), dtype=float32)
# Tensor("dense_99/LeakyRelu:0", shape=(?, 100, 1), dtype=float32)
# Tensor("transpose_199:0", shape=(?, 100, 1), dtype=float32)
